# %%
import os
PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
os.chdir(PROJ_ROOT)

# %%
import numpy as np
from numpy.linalg import inv as inv

# %%
import configparser
from configparser import ExtendedInterpolation

# %%
def kr_prod(a, b):
    return np.einsum('ir, jr -> ijr', a, b).reshape(a.shape[0] * b.shape[0], -1)

def cp_combine(U, V, X):
    return np.einsum('is, js, ts -> ijt', U, V, X)

def ten2mat(tensor, mode):
    return np.reshape(np.moveaxis(tensor, mode, 0), (tensor.shape[mode], -1), order = 'F')

# %%
# ALS algorithm for CP completion 
def CP_ALS(sparse_tensor_input, rank, maxiter, test_info = None):
    
    sparse_tensor = sparse_tensor_input.copy()
    dim1, dim2, dim3 = sparse_tensor.shape
    dim = np.array([dim1, dim2, dim3])
    U = 0.1 * np.random.rand(dim1, rank)
    V = 0.1 * np.random.rand(dim2, rank)
    X = 0.1 * np.random.rand(dim3, rank)
    
    pos = np.where(sparse_tensor != 0)
    binary_tensor = np.zeros((dim1, dim2, dim3))
    binary_tensor[pos] = 1
    tensor_hat = np.zeros((dim1, dim2, dim3))
    
    min_test_cls = 999
    min_test_cls_iteration = -1
    
    for iters in range(maxiter):
        for order in range(dim.shape[0]):
            if order == 0:
                var1 = kr_prod(X, V).T
            elif order == 1:
                var1 = kr_prod(X, U).T
            else:
                var1 = kr_prod(V, U).T
            var2 = kr_prod(var1, var1)
            var3 = np.matmul(var2, ten2mat(binary_tensor, order).T).reshape([rank, rank, dim[order]])
            var4 = np.matmul(var1, ten2mat(sparse_tensor, order).T)
            for i in range(dim[order]):
                var_Lambda = var3[ :, :, i]
                inv_var_Lambda = inv((var_Lambda + var_Lambda.T)/2 + 10e-12 * np.eye(rank))
                vec = np.matmul(inv_var_Lambda, var4[:, i])
                if order == 0:
                    U[i, :] = vec.copy()
                elif order == 1:
                    V[i, :] = vec.copy()
                else:
                    X[i, :] = vec.copy()

        tensor_hat = cp_combine(U, V, X)

        if (iters + 1) % 10 == 0:
            mape = np.sum(np.abs(sparse_tensor[pos] - tensor_hat[pos])/np.abs(sparse_tensor[pos]))/sparse_tensor[pos].shape[0]
            mape = np.sum(np.abs(sparse_tensor[pos] - tensor_hat[pos])/np.abs(sparse_tensor[pos]))/sparse_tensor[pos].shape[0]
            rmse = np.sqrt(np.sum((sparse_tensor[pos] - tensor_hat[pos]) ** 2)/sparse_tensor[pos].shape[0])
            print('Iter: {}'.format(iters + 1))
            print('Training MAPE: {:.6}'.format(mape))
            print('Training RMSE: {:.6}'.format(rmse))
            print()
            
            if test_info is not None:
                # print test mape and rmse 
                test_pos_tuple,  test_values = test_info
                
                norm_tcs = np.linalg.norm(test_values)
                error_tcs = np.linalg.norm(tensor_hat[test_pos_tuple] - test_values)
                test_tcs = error_tcs/norm_tcs
                
                test_rmse = np.sqrt(np.sum((test_values - tensor_hat[test_pos_tuple]) ** 2)\
                                    /test_values.shape[0])
                print('Testing TCS: {:.6}'.format(test_tcs))
                print('Testing RMSE: {:.6}'.format(test_rmse))
                print()
                
                ## stop iteration if smallest test_tcs get 
                
                if test_tcs < min_test_cls:
                    min_test_cls = test_tcs
                    min_test_cls_iteration = iters
                
                else:
                    if ((iters - min_test_cls_iteration) > 30):
                        break 
                    
    return tensor_hat, U, V, X, min_test_cls, min_test_cls_iteration

# %%
def choose_test_index_for_location(location_array, test_ratio = 0.2):
    np.random.seed(2020)
    location_choice = np.random.choice(location_array, size=int(len(location_array)*0.2), replace=False)
    return location_choice

# %%
def choose_test_index(pos, num_of_locations=50):
    test_index = np.array([])
    for loc_num in range(num_of_locations):
        location_array = np.where(pos[0] == loc_num)[0]
        location_choice = choose_test_index_for_location(location_array)
        location_choice.sort()
        test_index =  np.concatenate((test_index, location_choice), axis=0)
    return test_index

# %%
config_path = 'config/parameters.ini'
# read configuration from config file
pars = configparser.ConfigParser(interpolation=ExtendedInterpolation())
pars.read(config_path)
# Out:
# ['config/parameters.ini']

# %%
import pickle 
location_search_tensor_path = 'data/external/location_search_tensor.pkl'
location_tensor_array = pickle.load(open(location_search_tensor_path, 'rb'))
sparse_tensor = np.nan_to_num(location_tensor_array, copy=True, nan=0)
# create test sparse_tensor 
pos = np.where(sparse_tensor != 0)

# %%
test_index = choose_test_index(pos)
test_index = list(test_index.astype(int))
test_pos_tuple = tuple([pos[0][test_index], pos[1][test_index], pos[2][test_index]])
test_values = sparse_tensor[test_pos_tuple] 
sparse_tensor[test_pos_tuple] = 0

# %%
print(len(np.where(sparse_tensor != 0)[0]))
print(len(test_pos_tuple[0]))
# Out:
# 75104
# 18753

# %%
import time
rank = 10

# %%
rank_info_dict = {}

# %%
rank_info_dict
# Out:
# {}

# %%
for rank in [5, 10, 20, 40, 80]:
    start = time.time()
    print('Rank: ' + str(rank))
    print()
    maxiter = 700
    np.random.seed(10)
    tensor_hat, U, V, X, min_test_cls, min_test_cls_iteration = CP_ALS(sparse_tensor, rank, maxiter, test_info = (test_pos_tuple, test_values))
    end = time.time()
    print('Testing TCS: {:.6}'.format(min_test_cls))
    print('Testing iter: {}'.format(min_test_cls_iteration))
    print('Running time: %d seconds'%(end - start))
    rank_info_dict[rank] = [min_test_cls, min_test_cls_iteration]
# Out:
# Rank: 5
#
# Iter: 10
# Training MAPE: 0.468262
# Training RMSE: 4.82425
#
# Testing TCS: 0.189894
# Testing RMSE: 5.16104
#
# Iter: 20
# Training MAPE: 0.463717
# Training RMSE: 4.75637
#
# Testing TCS: 0.186969
# Testing RMSE: 5.08151
#
# Iter: 30
# Training MAPE: 0.463306
# Training RMSE: 4.70886
#
# Testing TCS: 0.184614
# Testing RMSE: 5.01751
#
# Iter: 40
# Training MAPE: 0.464035
# Training RMSE: 4.66374
#
# Testing TCS: 0.182592
# Testing RMSE: 4.96255
#
# Iter: 50
# Training MAPE: 0.463631
# Training RMSE: 4.6301
#
# Testing TCS: 0.181555
# Testing RMSE: 4.93437
#
# Iter: 60
# Training MAPE: 0.462611
# Training RMSE: 4.61161
#
# Testing TCS: 0.181199
# Testing RMSE: 4.92471
#
# Iter: 70
# Training MAPE: 0.46243
# Training RMSE: 4.60265
#
# Testing TCS: 0.181075
# Testing RMSE: 4.92134
#
# Iter: 80
# Training MAPE: 0.462326
# Training RMSE: 4.59811
#
# Testing TCS: 0.181031
# Testing RMSE: 4.92013
#
# Iter: 90
# Training MAPE: 0.462237
# Training RMSE: 4.59563
#
# Testing TCS: 0.181004
# Testing RMSE: 4.91941
#
# Iter: 100
# Training MAPE: 0.462159
# Training RMSE: 4.59419
#
# Testing TCS: 0.180982
# Testing RMSE: 4.9188
#
# Iter: 110
# Training MAPE: 0.462104
# Training RMSE: 4.59328
#
# Testing TCS: 0.180962
# Testing RMSE: 4.91825
#
# Iter: 120
# Training MAPE: 0.462062
# Training RMSE: 4.59268
#
# Testing TCS: 0.180944
# Testing RMSE: 4.91777
#
# Iter: 130
# Training MAPE: 0.462028
# Training RMSE: 4.59224
#
# Testing TCS: 0.180929
# Testing RMSE: 4.91736
#
# Iter: 140
# Training MAPE: 0.461999
# Training RMSE: 4.59191
#
# Testing TCS: 0.180916
# Testing RMSE: 4.91702
#
# Iter: 150
# Training MAPE: 0.461975
# Training RMSE: 4.59163
#
# Testing TCS: 0.180905
# Testing RMSE: 4.91672
#
# Iter: 160
# Training MAPE: 0.461953
# Training RMSE: 4.59139
#
# Testing TCS: 0.180896
# Testing RMSE: 4.91647
#
# Iter: 170
# Training MAPE: 0.461933
# Training RMSE: 4.59118
#
# Testing TCS: 0.180888
# Testing RMSE: 4.91625
#
# Iter: 180
# Training MAPE: 0.461916
# Training RMSE: 4.59099
#
# Testing TCS: 0.180881
# Testing RMSE: 4.91605
#
# Iter: 190
# Training MAPE: 0.461901
# Training RMSE: 4.59081
#
# Testing TCS: 0.180874
# Testing RMSE: 4.91586
#
# Iter: 200
# Training MAPE: 0.461888
# Training RMSE: 4.59064
#
# Testing TCS: 0.180867
# Testing RMSE: 4.91568
#
# Iter: 210
# Training MAPE: 0.461877
# Training RMSE: 4.59048
#
# Testing TCS: 0.18086
# Testing RMSE: 4.9155
#
# Iter: 220
# Training MAPE: 0.461869
# Training RMSE: 4.59033
#
# Testing TCS: 0.180853
# Testing RMSE: 4.91532
#
# Iter: 230
# Training MAPE: 0.461864
# Training RMSE: 4.59018
#
# Testing TCS: 0.180846
# Testing RMSE: 4.91512
#
# Iter: 240
# Training MAPE: 0.46186
# Training RMSE: 4.59004
#
# Testing TCS: 0.180839
# Testing RMSE: 4.91492
#
# Iter: 250
# Training MAPE: 0.461859
# Training RMSE: 4.58991
#
# Testing TCS: 0.180831
# Testing RMSE: 4.91472
#
# Iter: 260
# Training MAPE: 0.46186
# Training RMSE: 4.58978
#
# Testing TCS: 0.180823
# Testing RMSE: 4.9145
#
# Iter: 270
# Training MAPE: 0.461862
# Training RMSE: 4.58967
#
# Testing TCS: 0.180815
# Testing RMSE: 4.91427
#
# Iter: 280
# Training MAPE: 0.461864
# Training RMSE: 4.58955
#
# Testing TCS: 0.180806
# Testing RMSE: 4.91403
#
# Iter: 290
# Training MAPE: 0.461867
# Training RMSE: 4.58945
#
# Testing TCS: 0.180797
# Testing RMSE: 4.91378
#
# Iter: 300
# Training MAPE: 0.461871
# Training RMSE: 4.58935
#
# Testing TCS: 0.180788
# Testing RMSE: 4.91353
#
# Iter: 310
# Training MAPE: 0.461877
# Training RMSE: 4.58926
#
# Testing TCS: 0.180778
# Testing RMSE: 4.91326
#
# Iter: 320
# Training MAPE: 0.461882
# Training RMSE: 4.58917
#
# Testing TCS: 0.180768
# Testing RMSE: 4.913
#
# Iter: 330
# Training MAPE: 0.461886
# Training RMSE: 4.58908
#
# Testing TCS: 0.180758
# Testing RMSE: 4.91272
#
# Iter: 340
# Training MAPE: 0.461891
# Training RMSE: 4.589
#
# Testing TCS: 0.180748
# Testing RMSE: 4.91244
#
# Iter: 350
# Training MAPE: 0.461896
# Training RMSE: 4.58893
#
# Testing TCS: 0.180737
# Testing RMSE: 4.91216
#
# Iter: 360
# Training MAPE: 0.461901
# Training RMSE: 4.58886
#
# Testing TCS: 0.180727
# Testing RMSE: 4.91188
#
# Iter: 370
# Training MAPE: 0.461906
# Training RMSE: 4.58879
#
# Testing TCS: 0.180717
# Testing RMSE: 4.91159
#
# Iter: 380
# Training MAPE: 0.461911
# Training RMSE: 4.58873
#
# Testing TCS: 0.180706
# Testing RMSE: 4.91131
#
# Iter: 390
# Training MAPE: 0.461916
# Training RMSE: 4.58867
#
# Testing TCS: 0.180696
# Testing RMSE: 4.91102
#
# Iter: 400
# Training MAPE: 0.46192
# Training RMSE: 4.58861
#
# Testing TCS: 0.180685
# Testing RMSE: 4.91074
#
# Iter: 410
# Training MAPE: 0.461924
# Training RMSE: 4.58855
#
# Testing TCS: 0.180675
# Testing RMSE: 4.91046
#
# Iter: 420
# Training MAPE: 0.461929
# Training RMSE: 4.58849
#
# Testing TCS: 0.180664
# Testing RMSE: 4.91018
#
# Iter: 430
# Training MAPE: 0.461934
# Training RMSE: 4.58844
#
# Testing TCS: 0.180654
# Testing RMSE: 4.9099
#
# Iter: 440
# Training MAPE: 0.461939
# Training RMSE: 4.58839
#
# Testing TCS: 0.180644
# Testing RMSE: 4.90962
#
# Iter: 450
# Training MAPE: 0.461944
# Training RMSE: 4.58833
#
# Testing TCS: 0.180634
# Testing RMSE: 4.90935
#
# Iter: 460
# Training MAPE: 0.461949
# Training RMSE: 4.58828
#
# Testing TCS: 0.180624
# Testing RMSE: 4.90908
#
# Iter: 470
# Training MAPE: 0.461954
# Training RMSE: 4.58823
#
# Testing TCS: 0.180614
# Testing RMSE: 4.90881
#
# Iter: 480
# Training MAPE: 0.46196
# Training RMSE: 4.58818
#
# Testing TCS: 0.180604
# Testing RMSE: 4.90854
#
# Iter: 490
# Training MAPE: 0.461965
# Training RMSE: 4.58812
#
# Testing TCS: 0.180595
# Testing RMSE: 4.90828
#
# Iter: 500
# Training MAPE: 0.46197
# Training RMSE: 4.58807
#
# Testing TCS: 0.180585
# Testing RMSE: 4.90803
#
# Iter: 510
# Training MAPE: 0.461975
# Training RMSE: 4.58802
#
# Testing TCS: 0.180576
# Testing RMSE: 4.90777
#
# Iter: 520
# Training MAPE: 0.461979
# Training RMSE: 4.58796
#
# Testing TCS: 0.180567
# Testing RMSE: 4.90752
#
# Iter: 530
# Training MAPE: 0.461984
# Training RMSE: 4.58791
#
# Testing TCS: 0.180558
# Testing RMSE: 4.90727
#
# Iter: 540
# Training MAPE: 0.461988
# Training RMSE: 4.58785
#
# Testing TCS: 0.180549
# Testing RMSE: 4.90703
#
# Iter: 550
# Training MAPE: 0.461993
# Training RMSE: 4.58779
#
# Testing TCS: 0.18054
# Testing RMSE: 4.90679
#
# Iter: 560
# Training MAPE: 0.461997
# Training RMSE: 4.58772
#
# Testing TCS: 0.180531
# Testing RMSE: 4.90655
#
# Iter: 570
# Training MAPE: 0.462001
# Training RMSE: 4.58766
#
# Testing TCS: 0.180522
# Testing RMSE: 4.90632
#
# Iter: 580
# Training MAPE: 0.462004
# Training RMSE: 4.58759
#
# Testing TCS: 0.180514
# Testing RMSE: 4.90609
#
# Iter: 590
# Training MAPE: 0.462008
# Training RMSE: 4.58751
#
# Testing TCS: 0.180506
# Testing RMSE: 4.90586
#
# Iter: 600
# Training MAPE: 0.462011
# Training RMSE: 4.58743
#
# Testing TCS: 0.180497
# Testing RMSE: 4.90564
#
# Iter: 610
# Training MAPE: 0.462014
# Training RMSE: 4.58735
#
# Testing TCS: 0.180489
# Testing RMSE: 4.90542
#
# Iter: 620
# Training MAPE: 0.462017
# Training RMSE: 4.58726
#
# Testing TCS: 0.180482
# Testing RMSE: 4.90521
#
# Iter: 630
# Training MAPE: 0.46202
# Training RMSE: 4.58716
#
# Testing TCS: 0.180474
# Testing RMSE: 4.905
#
# Iter: 640
# Training MAPE: 0.462022
# Training RMSE: 4.58705
#
# Testing TCS: 0.180466
# Testing RMSE: 4.9048
#
# Iter: 650
# Training MAPE: 0.462023
# Training RMSE: 4.58694
#
# Testing TCS: 0.180459
# Testing RMSE: 4.9046
#
# Iter: 660
# Training MAPE: 0.462026
# Training RMSE: 4.58681
#
# Testing TCS: 0.180452
# Testing RMSE: 4.90442
#
# Iter: 670
# Training MAPE: 0.462027
# Training RMSE: 4.58667
#
# Testing TCS: 0.180446
# Testing RMSE: 4.90424
#
# Iter: 680
# Training MAPE: 0.462029
# Training RMSE: 4.58652
#
# Testing TCS: 0.18044
# Testing RMSE: 4.90407
#
# Iter: 690
# Training MAPE: 0.462032
# Training RMSE: 4.58636
#
# Testing TCS: 0.180434
# Testing RMSE: 4.90393
#
# Iter: 700
# Training MAPE: 0.462036
# Training RMSE: 4.58618
#
# Testing TCS: 0.18043
# Testing RMSE: 4.9038
#
# Testing TCS: 0.18043
# Testing iter: 699
# Running time: 32 seconds
# Rank: 10
#
# Iter: 10
# Training MAPE: 0.367153
# Training RMSE: 3.64109
#
# Testing TCS: 0.151619
# Testing RMSE: 4.12076
#
# Iter: 20
# Training MAPE: 0.363464
# Training RMSE: 3.59794
#
# Testing TCS: 0.15015
# Testing RMSE: 4.08085
#
# Iter: 30
# Training MAPE: 0.362959
# Training RMSE: 3.58374
#
# Testing TCS: 0.149763
# Testing RMSE: 4.07034
#
# Iter: 40
# Training MAPE: 0.362691
# Training RMSE: 3.56954
#
# Testing TCS: 0.151437
# Testing RMSE: 4.11581
#
# Iter: 50
# Training MAPE: 0.364036
# Training RMSE: 3.55637
#
# Testing TCS: 0.153623
# Testing RMSE: 4.17524
#
# Iter: 60
# Training MAPE: 0.364488
# Training RMSE: 3.54932
#
# Testing TCS: 0.154065
# Testing RMSE: 4.18723
#
# Iter: 70
# Training MAPE: 0.364584
# Training RMSE: 3.54416
#
# Testing TCS: 0.154204
# Testing RMSE: 4.19102
#
# Testing TCS: 0.149763
# Testing iter: 29
# Running time: 4 seconds
# Rank: 20
#
# Iter: 10
# Training MAPE: 0.329722
# Training RMSE: 2.92875
#
# Testing TCS: 0.164964
# Testing RMSE: 4.48347
#
# Iter: 20
# Training MAPE: 0.321749
# Training RMSE: 2.83253
#
# Testing TCS: 0.176704
# Testing RMSE: 4.80254
# Iter: 30
# Training MAPE: 0.316785
# Training RMSE: 2.77758
#
# Testing TCS: 0.193692
# Testing RMSE: 5.26425
#
# Iter: 40
# Training MAPE: 0.314616
# Training RMSE: 2.7563
#
# Testing TCS: 0.204789
# Testing RMSE: 5.56584
#
# Iter: 50
# Training MAPE: 0.313358
# Training RMSE: 2.74297
#
# Testing TCS: 0.209278
# Testing RMSE: 5.68785
#
# Testing TCS: 0.164964
# Testing iter: 9
# Running time: 7 seconds
# Rank: 40
#
# Iter: 10
# Training MAPE: 0.282768
# Training RMSE: 2.11266
#
# Testing TCS: 0.222368
# Testing RMSE: 6.04361
#
# Iter: 20
# Training MAPE: 0.27703
# Training RMSE: 2.03768
#
# Testing TCS: 0.241116
# Testing RMSE: 6.55316
#
# Iter: 30
# Training MAPE: 0.274048
# Training RMSE: 2.00156
#
# Testing TCS: 0.25812
# Testing RMSE: 7.01531
#
# Iter: 40
# Training MAPE: 0.272316
# Training RMSE: 1.97674
#
# Testing TCS: 0.269066
# Testing RMSE: 7.31281
#
# Iter: 50
# Training MAPE: 0.271255
# Training RMSE: 1.9584
#
# Testing TCS: 0.275031
# Testing RMSE: 7.47491
#
# Testing TCS: 0.222368
# Testing iter: 9
# Running time: 20 seconds
# Rank: 80
#
# Iter: 10
# Training MAPE: 0.239285
# Training RMSE: 1.46027
#
# Testing TCS: 164.201
# Testing RMSE: 4462.72
#
# Iter: 20
# Training MAPE: 0.230697
# Training RMSE: 1.36074
#
# Testing TCS: 159.982
# Testing RMSE: 4348.07
#
# Iter: 30
# Training MAPE: 0.227155
# Training RMSE: 1.32051
#
# Testing TCS: 157.192
# Testing RMSE: 4272.24
#
# Iter: 40
# Training MAPE: 0.224729
# Training RMSE: 1.29516
#
# Testing TCS: 164.496
# Testing RMSE: 4470.76
#
# Iter: 50
# Training MAPE: 0.223418
# Training RMSE: 1.27757
#
# Testing TCS: 167.645
# Testing RMSE: 4556.34
#
# Iter: 60
# Training MAPE: 0.22258
# Training RMSE: 1.26484
#
# Testing TCS: 135.181
# Testing RMSE: 3674.01
#
# Iter: 70
# Training MAPE: 0.221354
# Training RMSE: 1.25468
#
# Testing TCS: 135.742
# Testing RMSE: 3689.25
#
# Iter: 80
# Training MAPE: 0.220571
# Training RMSE: 1.24654
#
# Testing TCS: 132.903
# Testing RMSE: 3612.11
#
# Iter: 90
# Training MAPE: 0.219663
# Training RMSE: 1.23973
#
# Testing TCS: 129.084
# Testing RMSE: 3508.31
#
# Iter: 100
# Training MAPE: 0.218928
# Training RMSE: 1.23367
#
# Testing TCS: 13.5815
# Testing RMSE: 369.123
#
# Iter: 110
# Training MAPE: 0.219588
# Training RMSE: 1.22927
#
# Testing TCS: 4.65515
# Testing RMSE: 126.52
#
# Iter: 120
# Training MAPE: 0.218572
# Training RMSE: 1.22136
#
# Testing TCS: 5.74117
# Testing RMSE: 156.036
#
# Iter: 130
# Training MAPE: 0.217225
# Training RMSE: 1.21474
#
# Testing TCS: 7.89048
# Testing RMSE: 214.451
#
# Iter: 140
# Training MAPE: 0.216382
# Training RMSE: 1.20964
#
# Testing TCS: 11.1734
# Testing RMSE: 303.675
#
# Iter: 150
# Training MAPE: 0.216046
# Training RMSE: 1.20557
#
# Testing TCS: 23.1271
# Testing RMSE: 628.559
#
# Testing TCS: 4.65515
# Testing iter: 109
# Running time: 240 seconds

# %%
import pandas as pd
rank_info_pd = pd.DataFrame(rank_info_dict).T

# %%
min_row = rank_info_pd[rank_info_pd[0] == rank_info_pd[0].min()]

# %%
best_rank = min_row.index[0]

# %%
best_iter = int(min_row[1] + 1)

# %%
best_rank
# Out:
# 10

# %%
loc_tensor = np.nan_to_num(location_tensor_array, copy=True, nan=0)
# create test sparse_tensor 
pos = np.where(loc_tensor != 0)
print(len(pos[0]))
# Out:
# 93857

# %%
np.random.seed(10)
tensor_hat, U, V, X, min_test_cls, min_test_cls_iteration = CP_ALS(loc_tensor, best_rank, best_iter, test_info = None)
# Out:
# Iter: 10
# Training MAPE: 0.369839
# Training RMSE: 3.67186
#
# Iter: 20
# Training MAPE: 0.362667
# Training RMSE: 3.62693
#
# Iter: 30
# Training MAPE: 0.360433
# Training RMSE: 3.61304

# %%
imputed_save_path = 'data/external/imputed_tensor_array.pkl'

# %%
pickle.dump(tensor_hat, open(imputed_save_path, 'wb'))

# %%
np.random.rand(10, 10)
# Out:
# array([[0.28208046, 0.42902209, 0.60881578, 0.10529745, 0.71388675,
#         0.92436679, 0.3215174 , 0.08982099, 0.61858301, 0.27757761],
#        [0.44894571, 0.29109628, 0.38945601, 0.24276079, 0.31831308,
#         0.80394262, 0.08823857, 0.06748663, 0.39247303, 0.4635031 ],
#        [0.18785696, 0.50746823, 0.66365047, 0.36725844, 0.64431549,
#         0.9936906 , 0.5693492 , 0.54378324, 0.62786684, 0.94811119],
#        [0.77188159, 0.47028695, 0.01429415, 0.27996584, 0.41644882,
#         0.90234388, 0.81468965, 0.42867465, 0.48564143, 0.74732602],
#        [0.28409757, 0.09296883, 0.09294327, 0.52782895, 0.6138759 ,
#         0.53584455, 0.68153912, 0.89757469, 0.97227988, 0.26726937],
#        [0.26003433, 0.95209319, 0.78470666, 0.06388887, 0.80737222,
#         0.67839269, 0.94759288, 0.66188065, 0.10587892, 0.62708692],
#        [0.31896491, 0.62993584, 0.45765399, 0.32925796, 0.9206549 ,
#         0.75684575, 0.77050882, 0.93704153, 0.3552869 , 0.15349886],
#        [0.22491033, 0.70717823, 0.4190647 , 0.19720845, 0.46479471,
#         0.76498779, 0.90587377, 0.04082034, 0.51100274, 0.86324169],
#        [0.49203181, 0.37550545, 0.50609264, 0.41291224, 0.96804095,
#         0.1527617 , 0.56796839, 0.40478821, 0.84784355, 0.80327956],
#        [0.518388  , 0.72172984, 0.78397696, 0.62298457, 0.52092023,
#         0.04189273, 0.0926326 , 0.15073048, 0.38752805, 0.80743927]])

# %%
rank_info_dict

# %%
min_test_cls

# %%
min_test_cls_iteration

# %%
def tenerror(fitx, realx, omega):
    """
    Calculate Three Kinds of Error
    :param fitx: fitted tensor
    :param realx: ground-truth tensor
    :param omega: index tensor of observed entries
    """

#     if type(omega) != np.ndarray and type(omega) != pyten.tenclass.Tensor:
#         raise ValueError("AirCP: cannot recognize the format of observed Tensor!")
#     elif type(omega) == pyten.tenclass.Tensor:
#         omega = omega.tondarray
#     if type(realx) == np.ndarray:
#         realx = pyten.tenclass.Tensor(realx)
#     if type(fitx) == np.ndarray:
#         realx = pyten.tenclass.Tensor(realx)
    norm1 = np.linalg.norm(realx)
    norm2 = np.linalg.norm(realx * (1 - omega))
    err1 = np.linalg.norm(fitx - realx)  # Absolute Error
    err2 = np.linalg.norm((fitx - realx) * (1 - omega))
    re_err1 = err1 / norm1  # Relative Error 1
    re_err2 = err2 / norm2  # Relative Error 2
    return err1, re_err1, re_err2
